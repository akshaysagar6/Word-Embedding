# %%
import pandas as pd
import re 
import numpy as np
from nltk.corpus import stopwords

# %%
df=pd.read_csv(r"C:\Users\aksha\Downloads\all_kindle_review.csv")
df
# Out:
#        Unnamed: 0.1  Unnamed: 0        asin  helpful  rating  \
# 0                 0       11539  B0033UV8HI  [8, 10]       3
# 1                 1        5957  B002HJV4DE   [1, 1]       5
# 2                 2        9146  B002ZG96I4   [0, 0]       3
# 3                 3        7038  B002QHWOEU   [1, 3]       3
# 4                 4        1776  B001A06VJ8   [0, 1]       4
# ...             ...         ...         ...      ...     ...
# 11995         11995        2183  B001DUGORO   [0, 0]       4
# 11996         11996        6272  B002JCSFSQ   [2, 2]       5
# 11997         11997       12483  B0035N1V7K   [0, 1]       3
# 11998         11998        3640  B001W1XT40   [1, 2]       1
# 11999         11999       11398  B003370JUS   [5, 6]       3
#
#                                               reviewText   reviewTime  \
# 0      Jace Rankin may be short, but he's nothing to ...   09 2, 2010
# 1      Great short read.  I didn't want to put it dow...   10 8, 2013
# ...

# %%
newdf=df[['reviewText','rating']]
newdf
# Out:
#                                               reviewText  rating
# 0      Jace Rankin may be short, but he's nothing to ...       3
# 1      Great short read.  I didn't want to put it dow...       5
# 2      I'll start by saying this is the first of four...       3
# 3      Aggie is Angela Lansbury who carries pocketboo...       3
# 4      I did not expect this type of book to be in li...       4
# ...                                                  ...     ...
# 11995  Valentine cupid is a vampire- Jena and Ian ano...       4
# 11996  I have read all seven books in this series. Ap...       5
# 11997  This book really just wasn't my cuppa.  The si...       3
# 11998  tried to use it to charge my kindle, it didn't...       1
# 11999  Taking Instruction is a look into the often hi...       3
#
# [12000 rows x 2 columns]

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   reviewText  12000 non-null  object
#  1   rating      12000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 187.6+ KB

# %%
newdf.isnull().sum()
# Out:
# reviewText    0
# rating        0
# dtype: int64

# %%
newdf.duplicated().sum()
# Out:
# 0

# %%
newdf['rating'].unique()
# Out:
# array([3, 5, 4, 2, 1], dtype=int64)

# %%
newdf['rating'].value_counts()
# Out:
# 5    3000
# 4    3000
# 3    2000
# 2    2000
# 1    2000
# Name: rating, dtype: int64

# %%
newdf['reviewText']
# Out:
# 0        Jace Rankin may be short, but he's nothing to ...
# 1        Great short read.  I didn't want to put it dow...
# 2        I'll start by saying this is the first of four...
# 3        Aggie is Angela Lansbury who carries pocketboo...
# 4        I did not expect this type of book to be in li...
#                                ...
# 11995    Valentine cupid is a vampire- Jena and Ian ano...
# 11996    I have read all seven books in this series. Ap...
# 11997    This book really just wasn't my cuppa.  The si...
# 11998    tried to use it to charge my kindle, it didn't...
# 11999    Taking Instruction is a look into the often hi...
# Name: reviewText, Length: 12000, dtype: object

# %%
newdf['rating']=newdf['rating'].apply(lambda x:0 if x<3 else 1)
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_16644\2439304314.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['rating']=newdf['rating'].apply(lambda x:0 if x<3 else 1)

# %%
newdf
# Out:
#                                               reviewText  rating
# 0      Jace Rankin may be short, but he's nothing to ...       1
# 1      Great short read.  I didn't want to put it dow...       1
# 2      I'll start by saying this is the first of four...       1
# 3      Aggie is Angela Lansbury who carries pocketboo...       1
# 4      I did not expect this type of book to be in li...       1
# ...                                                  ...     ...
# 11995  Valentine cupid is a vampire- Jena and Ian ano...       1
# 11996  I have read all seven books in this series. Ap...       1
# 11997  This book really just wasn't my cuppa.  The si...       1
# 11998  tried to use it to charge my kindle, it didn't...       0
# 11999  Taking Instruction is a look into the often hi...       1
#
# [12000 rows x 2 columns]

# %%
newdf['rating'].value_counts()
# Out:
# 1    8000
# 0    4000
# Name: rating, dtype: int64

# %%
newdf['reviewText']=[x.lower() for x in newdf['reviewText']]
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_16644\2821446054.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['reviewText']=[x.lower() for x in newdf['reviewText']]

# %%
newdf
# Out:
#                                               reviewText  rating
# 0      jace rankin may be short, but he's nothing to ...       1
# 1      great short read.  i didn't want to put it dow...       1
# 2      i'll start by saying this is the first of four...       1
# 3      aggie is angela lansbury who carries pocketboo...       1
# 4      i did not expect this type of book to be in li...       1
# ...                                                  ...     ...
# 11995  valentine cupid is a vampire- jena and ian ano...       1
# 11996  i have read all seven books in this series. ap...       1
# 11997  this book really just wasn't my cuppa.  the si...       1
# 11998  tried to use it to charge my kindle, it didn't...       0
# 11999  taking instruction is a look into the often hi...       1
#
# [12000 rows x 2 columns]

# %%
newdf['reviewText']=newdf['reviewText'].apply(lambda x:re.sub('[^a-zA-Z]',' ',x))
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_16644\400656872.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['reviewText']=newdf['reviewText'].apply(lambda x:re.sub('[^a-zA-Z]',' ',x))

# %%
newdf
# Out:
#                                               reviewText  rating
# 0      jace rankin may be short  but he s nothing to ...       1
# 1      great short read   i didn t want to put it dow...       1
# 2      i ll start by saying this is the first of four...       1
# 3      aggie is angela lansbury who carries pocketboo...       1
# 4      i did not expect this type of book to be in li...       1
# ...                                                  ...     ...
# 11995  valentine cupid is a vampire  jena and ian ano...       1
# 11996  i have read all seven books in this series  ap...       1
# 11997  this book really just wasn t my cuppa   the si...       1
# 11998  tried to use it to charge my kindle  it didn t...       0
# 11999  taking instruction is a look into the often hi...       1
#
# [12000 rows x 2 columns]

# %%
stopwords=stopwords.words('english')

# %%
newdf['reviewText']=newdf['reviewText'].apply(lambda x:" ".join([y for y in x.split() if y not in stopwords]))
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_16644\2485679009.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['reviewText']=newdf['reviewText'].apply(lambda x:" ".join([y for y in x.split() if y not in stopwords]))

# %%
newdf
# Out:
#                                               reviewText  rating
# 0      jace rankin may short nothing mess man hauled ...       1
# 1      great short read want put read one sitting sex...       1
# 2      start saying first four books expecting conclu...       1
# 3      aggie angela lansbury carries pocketbooks inst...       1
# 4      expect type book library pleased find price right       1
# ...                                                  ...     ...
# 11995  valentine cupid vampire jena ian another vampi...       1
# 11996  read seven books series apocalyptic adventure ...       1
# 11997  book really cuppa situation man capturing woma...       1
# 11998  tried use charge kindle even register charging...       0
# 11999  taking instruction look often hidden world sex...       1
#
# [12000 rows x 2 columns]

# %%
newdf['reviewText']=newdf['reviewText'].apply(lambda x: re.sub(r'https?://\S+|www\.\S+',' ',x))
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_16644\3007338733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['reviewText']=newdf['reviewText'].apply(lambda x: re.sub(r'https?://\S+|www\.\S+',' ',x))

# %%
newdf
# Out:
#                                               reviewText  rating
# 0      jace rankin may short nothing mess man hauled ...       1
# 1      great short read want put read one sitting sex...       1
# 2      start saying first four books expecting conclu...       1
# 3      aggie angela lansbury carries pocketbooks inst...       1
# 4      expect type book library pleased find price right       1
# ...                                                  ...     ...
# 11995  valentine cupid vampire jena ian another vampi...       1
# 11996  read seven books series apocalyptic adventure ...       1
# 11997  book really cuppa situation man capturing woma...       1
# 11998  tried use charge kindle even register charging...       0
# 11999  taking instruction look often hidden world sex...       1
#
# [12000 rows x 2 columns]

# %%
newdf['reviewText']=newdf['reviewText'].apply(lambda x: " ".join(x.split()))
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_16644\1877570522.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['reviewText']=newdf['reviewText'].apply(lambda x: " ".join(x.split()))

# %%
newdf
# Out:
#                                               reviewText  rating
# 0      jace rankin may short nothing mess man hauled ...       1
# 1      great short read want put read one sitting sex...       1
# 2      start saying first four books expecting conclu...       1
# 3      aggie angela lansbury carries pocketbooks inst...       1
# 4      expect type book library pleased find price right       1
# ...                                                  ...     ...
# 11995  valentine cupid vampire jena ian another vampi...       1
# 11996  read seven books series apocalyptic adventure ...       1
# 11997  book really cuppa situation man capturing woma...       1
# 11998  tried use charge kindle even register charging...       0
# 11999  taking instruction look often hidden world sex...       1
#
# [12000 rows x 2 columns]

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemm=WordNetLemmatizer()

# %%
newdf['reviewText']=newdf['reviewText'].apply(lambda x :' '.join(lemm.lemmatize(y) for y in x.split()))
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_16644\3680779667.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['reviewText']=newdf['reviewText'].apply(lambda x :' '.join(lemm.lemmatize(y) for y in x.split()))

# %%
newdf
# Out:
#                                               reviewText  rating
# 0      jace rankin may short nothing mess man hauled ...       1
# 1      great short read want put read one sitting sex...       1
# 2      start saying first four book expecting conclud...       1
# 3      aggie angela lansbury carry pocketbook instead...       1
# 4      expect type book library pleased find price right       1
# ...                                                  ...     ...
# 11995  valentine cupid vampire jena ian another vampi...       1
# 11996  read seven book series apocalyptic adventure o...       1
# 11997  book really cuppa situation man capturing woma...       1
# 11998  tried use charge kindle even register charging...       0
# 11999  taking instruction look often hidden world sex...       1
#
# [12000 rows x 2 columns]

# %%
import gensim
from gensim.models import Word2Vec,keyedvectors

# %%
corpus=[x.split() for x in newdf['reviewText'].values]

# %%
corpus[2]
# Out:
# ['start',
#  'saying',
#  'first',
#  'four',
#  'book',
#  'expecting',
#  'conclude',
#  'center',
#  'child',
#  'alex',
#  'younger',
#  'brother',
#  'argus',
#  'alex',
#  'friend',
#  'sapphire',
#  'find',
#  'name',
#  'bus',
#  'map',
#  'find',
#  'mystery',
#  'start',
#  'well',
#  'written',
#  'good',
#  'character',
#  'development',
#  'although',
#  'lot',
#  'room',
#  'still',
#  'quite',
#  'short',
#  'book',
#  'moving',
#  'onto',
#  'book',
#  'swiftly']

# %%
len(corpus)
# Out:
# 12000

# %%
model=gensim.models.Word2Vec(corpus)

# %%
model.wv.index_to_key
# Out:
# ['book',
#  'story',
#  'read',
#  'one',
#  'character',
#  'like',
#  'good',
#  'would',
#  'love',
#  'really',
#  'time',
#  'get',
#  'author',
#  'series',
#  'well',
#  'reading',
#  'much',
#  'first',
#  'even',
#  'short',
#  'way',
#  'great',
#  'could',
#  'know',
#  'sex',
#  'make',
#  'little',
#  'two',
#  'thing',
#  'want',
#  'plot',
#  'think',
#  'romance',
#  'also',
#  'find',
#  'end',
#  'life',
#  'see',
#  'scene',
#  'go',
#  'enjoyed',
#  'never',
#  'written',
#  'woman',
#  'take',
#  'kindle',
#  'many',
#  'lot',
#  'year',
#  'work',
#  'say',
#  'thought',
#  'interesting',
#  'bit',
#  'going',
#  'found',
#  'novel',
#  'writing',
#  'give',
#  'another',
#  'liked',
#  'loved',
#  'better',
#  'man',
#  'hot',
#  'star',
#  'feel',
#  'got',
#  'come',
#  'review',
#  'still',
#  'though',
#  'back',
#  'reader',
#  'enough',
#  'people',
#  'friend',
#  'something',
#  'made',
#  'page',
#  'part',
#  'world',
#  'bad',
#  'free',
#  'need',
# ...

# %%
model.wv.most_similar('hi')
# Out:
# [('goodbye', 0.9773606061935425),
#  ('shocked', 0.9759849905967712),
#  ('whenever', 0.9725853800773621),
#  ('gosh', 0.971737802028656),
#  ('twice', 0.9704851508140564),
#  ('hello', 0.9690552353858948),
#  ('load', 0.9669899344444275),
#  ('disgusting', 0.966912031173706),
#  ('fooled', 0.9666743874549866),
#  ('marked', 0.9665001034736633)]

# %%
# average word2vec
def avg_word2vec(doc):
    valid_words=[model.wv[word] for word in doc if word in model.wv.key_to_index ]
    if valid_words:
        return np.mean(valid_words,axis=0)
    else:
        # Return a zero vector if no valid words are found
        return np.zeros(model.wv.vector_size)

# %%
x=[]
for i in range(len(corpus)):
    x.append(avg_word2vec(corpus[i]))

# %%
x_df=pd.DataFrame(x)

# %%
x_df
# Out:
#              0         1         2         3         4         5         6   \
# 0     -0.187601  0.488329  0.105733 -0.010120  0.113262 -0.375851  0.190054
# 1     -0.266342  0.368147 -0.048867  0.288567 -0.132326 -0.432167  0.295484
# 2     -0.240171  0.497436 -0.070508  0.127982  0.039733 -0.513226  0.204158
# 3     -0.167031  0.414066 -0.107031  0.166184  0.143308 -0.557300  0.353295
# 4     -0.081210  0.284755  0.110544 -0.029319 -0.011647 -0.593719  0.099712
# ...         ...       ...       ...       ...       ...       ...       ...
# 11995 -0.738496  0.721673  0.108517  0.130935 -0.183875 -0.205455 -0.094735
# 11996 -0.362189  0.280597 -0.065781  0.171844 -0.195421 -0.671836  0.097519
# 11997 -0.416175  0.300344  0.006099  0.211335 -0.052111 -0.394981  0.287483
# 11998  0.258672  0.486384  0.117804 -0.263292  0.449312 -0.490289  0.256779
# 11999 -0.102659  0.310223  0.033087  0.149886  0.083016 -0.549425  0.354038
#
# ...

# %%
newdf
# Out:
#                                               reviewText  rating
# 0      jace rankin may short nothing mess man hauled ...       1
# 1      great short read want put read one sitting sex...       1
# 2      start saying first four book expecting conclud...       1
# 3      aggie angela lansbury carry pocketbook instead...       1
# 4      expect type book library pleased find price right       1
# ...                                                  ...     ...
# 11995  valentine cupid vampire jena ian another vampi...       1
# 11996  read seven book series apocalyptic adventure o...       1
# 11997  book really cuppa situation man capturing woma...       1
# 11998  tried use charge kindle even register charging...       0
# 11999  taking instruction look often hidden world sex...       1
#
# [12000 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x_df,newdf['rating'],train_size=0.8)

# %%
print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)
print(ytest.shape)
# Out:
# (9600, 100)
# (2400, 100)
# (9600,)
# (2400,)

# %%
xtrain
# Out:
#              0         1         2         3         4         5         6   \
# 6614  -0.195358  0.436523 -0.000188  0.109852  0.135951 -0.479459  0.205218
# 7899   0.075051  0.283232 -0.036748  0.092487  0.096391 -0.580433  0.375393
# 10175 -0.197626  0.267626  0.076859  0.505880 -0.243383 -0.466768  0.173431
# 9236  -0.203916  0.484117  0.002114  0.174035  0.012916 -0.433593  0.159688
# 7224  -0.183938 -0.045302 -0.010720  0.203487 -0.129784 -0.663718  0.291985
# ...         ...       ...       ...       ...       ...       ...       ...
# 3589   0.064375  0.250927  0.055482 -0.006912  0.168048 -0.778426  0.356022
# 2764  -0.055898  0.226543 -0.116740  0.351143 -0.068247 -0.435464  0.225150
# 6954   0.002299  0.258901  0.009853  0.220514 -0.125482 -0.293439  0.230692
# 5972  -0.579185  0.060249 -0.094402  0.497553 -0.319138 -0.669988  0.360720
# 6475  -0.283491  0.304585  0.141036  0.128971 -0.036125 -0.522113  0.249434
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
nm=RandomForestClassifier(n_estimators=100).fit(xtrain,ytrain)

# %%
from sklearn.metrics import classification_report

# %%
trainpredt=nm.predict(xtrain)
print(classification_report(trainpredt,ytrain))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3187
#            1       1.00      1.00      1.00      6413
#
#     accuracy                           1.00      9600
#    macro avg       1.00      1.00      1.00      9600
# weighted avg       1.00      1.00      1.00      9600

# %%
testpredt=nm.predict(xtest)
print(classification_report(testpredt,ytest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.69      0.60       620
#            1       0.88      0.78      0.83      1780
#
#     accuracy                           0.76      2400
#    macro avg       0.70      0.74      0.71      2400
# weighted avg       0.79      0.76      0.77      2400

# %% [markdown]
# ### bag of words and TFIDF

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

# %%
bow=CountVectorizer()
tf=TfidfVectorizer()

# %%
newdf
# Out:
#                                               reviewText  rating
# 0      jace rankin may short nothing mess man hauled ...       1
# 1      great short read want put read one sitting sex...       1
# 2      start saying first four book expecting conclud...       1
# 3      aggie angela lansbury carry pocketbook instead...       1
# 4      expect type book library pleased find price right       1
# ...                                                  ...     ...
# 11995  valentine cupid vampire jena ian another vampi...       1
# 11996  read seven book series apocalyptic adventure o...       1
# 11997  book really cuppa situation man capturing woma...       1
# 11998  tried use charge kindle even register charging...       0
# 11999  taking instruction look often hidden world sex...       1
#
# [12000 rows x 2 columns]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(newdf['reviewText'],newdf['rating'],train_size=0.8)

# %%
xtrain.shape
# Out:
# (9600,)

# %%
xtest.shape
# Out:
# (2400,)

# %%
xtrain_bow = bow.fit_transform(xtrain)
xtest_bow = bow.transform(xtest)

xtrain_tf=tf.fit_transform(xtrain)
xtest_tf=tf.transform(xtest)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
modelB=MultinomialNB().fit(xtrain_bow,ytrain)
modelT=MultinomialNB().fit(xtrain_tf,y_train)

# %%
trainpredt=modelB.predict(xtrain_bow)
print(classification_report(trainpredt,ytrain))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86      3329
#            1       0.92      0.94      0.93      6271
#
#     accuracy                           0.91      9600
#    macro avg       0.90      0.89      0.90      9600
# weighted avg       0.91      0.91      0.91      9600

# %%
testpredt=modelB.predict(xtest_bow)
print(classification_report(testpredt,ytest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.76      0.75       776
#            1       0.88      0.87      0.88      1624
#
#     accuracy                           0.83      2400
#    macro avg       0.81      0.82      0.81      2400
# weighted avg       0.84      0.83      0.83      2400

# %%
trainpredt=modelT.predict(xtrain_tf)
print(classification_report(trainpredt,ytrain))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.33      0.01        27
#            1       1.00      0.67      0.80      9573
#
#     accuracy                           0.67      9600
#    macro avg       0.50      0.50      0.40      9600
# weighted avg       0.99      0.67      0.80      9600

# %%
testpredt=modelT.predict(xtest_tf)
print(classification_report(testpredt,ytest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.66      0.80      2400
#
#     accuracy                           0.66      2400
#    macro avg       0.50      0.33      0.40      2400
# weighted avg       1.00      0.66      0.80      2400
# C:\Users\aksha\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\aksha\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...
